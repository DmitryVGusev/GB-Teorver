# %% [markdown]
# # Теория вероятностей и математическая статистика
# ## Домашнее задание по уроку 5

# %%
import numpy as np
from scipy import stats

# %% [markdown]
# ### Задача 1
#
# Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя уровень значимости 0.025 и правостороннюю критическую область, проверить данную гипотезу при условии, что в выборке из 100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 мм.

# %% [markdown]
# #### Решение
# Размер шарика подшипника - нормально распределенная величина. Изначально выдвинутая гипотеза состоит в том, что средняя величина размера шарика подшипника = 17 мм

# %% [markdown]
# Выдвиним альтернативную гипотезу, что в выборке из 100 шариков средний диаметр оказался равным 17.5 мм. Уровень значимости $\alpha$ = 0.05
#
# Далее, определим критическую область. При $\alpha$ = 0.05 мы фактически ищем область двух сигм: значения величины $T$ с вероятностью 0.95 попадают в интервал:
# $$\left( 17 - \dfrac{4}{\sqrt{n}}, 17 + \dfrac{4}{\sqrt{n}} \right).$$
#
# Поэтому для нашего выбора $\alpha$ подойдёт двусторонняя критическая область
# $$\left( - \infty, 17 - \dfrac{4}{\sqrt{n}} \right) \cup \left( 17 + \dfrac{4}{\sqrt{n}}, \infty \right).$$
# что при выборке в 100 шариков будет иметь вид
# $$\left( - \infty, 16.6 \right) \cup \left( 17.4, \infty \right).$$
# нас же интересует только правосторонняя область:
# $$\left( 17.4, \infty \right)$$

# %% [markdown]
# А раз альтернативная гипотеза $(a=17.5)$ попадает в критическую область, значит она неверна

# %% [markdown]
# ### Задача 2
#
# Известно, что генеральная совокупность распределена нормально с известным средним квадратическим отклонением 16. Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95, если выборочное среднее равно 80, а объём равен 256.

# %% [markdown]
# #### Решение
# Раз при нормальном распределении a = 80 и $\sigma = \sqrt{\frac{D(X)}{n}}= \frac{16}{\sqrt{256}} = 1$, мы можем из имеющихся данных построить доверительный интервал. Надежность в 0.95 намекает о возможности использовать правило двух сигм:
# $$\left( a - 2\sigma, a + 2\sigma \right) = \left( 78, 82 \right)$$

# %% [markdown]
# ### Задача 3a
#
# Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет:
#
# 202, 203, 199, 197, 195, 201, 200, 204, 194, 190
#
# Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что уровень значимости равен 1% ?

# %% [markdown]
# #### Решение
# Имея на руках отобранную партию печенья, найдем их среднее и несмещённую оценку для среднего квадратического отклонения:

# %%
cookes = np.array([202, 203, 199, 197, 195, 201, 200, 204, 194, 190])
m = cookes.mean()
s = cookes.std()
m,s
# Out:
# (198.5, 4.224926034855522)

# %% [markdown]
# Из таблицы квантилий при доверительной вероятности $\alpha = 0.01$ получаем

# %%
t = 3.2498

# %% [markdown]
# И строим доверительный интервал для нормального распределения:

# %%
n = 10
(m - t * s / np.sqrt(n), m + t * s / np.sqrt(n))
# Out:
# (194.1581407126209, 202.8418592873791)

# %% [markdown]
# Из чего следует что утверждение продавца при данной доверительнй вероятности не опровергнута
