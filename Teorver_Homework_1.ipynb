# %% [markdown]
# ## Домашнее задание по уроку 1

# %%
import numpy as np

# %% [markdown]
# ### Задача 1
#
# Вернёмся к примеру 2. Чтобы посчитать вероятность такого события, нужно использовать сочетания или размещения? Ответ необходимо обосновать.

# %% [markdown]
# #### Решение

# %% [markdown]
# Поскольку порядок выпадения чисел задан *(найти частоту случайного события 𝐵, при котором на первой кости выпало 1, а на второй - 2)* - необходимо использовать размещения.

# %% [markdown]
# ### Задача 2
#
# Группа студентов изучает $10$ различных дисциплин. Сколькими способами можно составить расписание на понедельник, если в этот день должно быть $4$ разных занятия?

# %% [markdown]
# #### Решение

# %% [markdown]
# Так как нам необходимо выбрать 4 дисциплины из 10, соблюдая очередность, воспользуемся формулой размещения:
# $$A_n^k = \frac{n!}{(n - k)!}$$
# где
# * $n$ - количество различных дисциплин,
# * $k$ - количество занятий

# %%
np.math.factorial(10)//np.math.factorial(10-4)
# Out:
# 5040

# %% [markdown]
# ### Задача 3
#
# Семь человек рассаживаются наудачу на скамейке. Какова вероятность того, что два определённых человека будут сидеть рядом?

# %% [markdown]
# #### Решение

# %% [markdown]
# Рассмотрим вероятность того, что первым сел определенный человек. Вероятность этого составляет $\frac{2}{7}$. При этом, вероятность того, что правее сел второй определенный человек - $\frac{1}{6}$. Проходясь по всем местам на лавочке, кроме последнего, используя формулу полной вероятности, находим общую вероятоность что на лавочке друг с другом сидят два определенных человека:
# $$ P =  (\frac{2}{7} \cdot \frac{1}{6}) \cdot (7-1) = \frac{2}{7}$$

# %% [markdown]
# ### Задача 4
#
# Из $60$ вопросов, входящих в экзаменационные билеты, студент знает $50$. Какова вероятность того, что среди трёх наугад выбранных вопросов студент знает: а) все? б) два?

# %% [markdown]
# #### Решение

# %% [markdown]
# а) Вероятность того что, студент знает все билеты = $\frac{50}{60} \cdot \frac{49}{59} \cdot \frac{48}{58} = 0.572$

# %%
(50/60) * (49/59) * (48/58)
# Out:
# 0.5727644652250146

# %% [markdown]
# а) При вероятности того что, студент знает два билета, можно считать, что студент уже вынул один билет который он не знает, а значит вероятность = $\frac{50}{59} \cdot \frac{49}{58} = 0.715$

# %%
(50/59) * (49/58)
# Out:
# 0.7159555815312683

# %% [markdown]
# ### Задача 5
#
# Бросается игральная кость. Пусть событие $A$ - появление чётного числа, событие $B$ - появление числа больше трёх. Являются ли эти события независимыми?

# %% [markdown]
# #### Ответ
# Эти события совместные, но не зависимые.
# Вероятность одновременного появления двух независимых событий вычисляется по формуле: $$P(AB) = P(A) \cdot P(B)$$
#
# В нашем случае, вероятность события  $A - \frac{1}2 \space (2,4,6)$
#
# Вероятность события $B - \frac{1}2 \space (4,5,6) $
#
# И вероятность появления двух одновременных событий
# $$P(AB) = P(A) \cdot P(B) = \frac{1}2 \cdot \frac{1}2 = \frac{1}{4}$$

# %% [markdown]
# ### Задача 6
#
# Допустим, имеется некоторая очень редкая болезнь (поражает $0.1 \%$ населения). Вы приходите к врачу, вам делают тест на эту болезнь, и тест оказывается положительным. Врач говорит вам, что этот тест верно выявляет $99 \%$ больных этой болезнью и всего лишь в $1 \%$ случаев даёт ложный положительный ответ.
#
# _Вопрос_: вакова вероятность, что вы действительно больны ей?
#
# _Подсказка_: вновь используйте формулу Байеса с раскрытием знаменателя с помощью формулы полной вероятности.

# %% [markdown]
# #### Решение

# %% [markdown]
# Пусть событие $A$ заключается в том, что тест дал положительный результат, и пусть событие $B_2$ заключается в том, что я болен этой болезнью и $B_1$ - что не болен. Из условий следует, что тест может дать 1% вероятности ложно-положительного результата даже если я не болен, то есть $P(A|B_1) = \frac{1}{100}$.
#
# Применяя формулу Байеса, получим:
# $$
# P(B_2\:|\:A) = \frac{P(A\:|\:B_2) \cdot P(B_2)}{P(A)} =
# \frac{P(A\:|\:B_2) \cdot P(B_2)}{P(A\:|\:B_2) \cdot P(B_2) + P(A\:|\:B_1) \cdot P(B_1)}= \\
# = \frac
#     {\frac{99}{100} \cdot \frac{1}{1000}}
#     {\frac{99}{100} \cdot \frac{1}{1000} + \frac{1}{100} \cdot \frac{99}{1000}}
# = \frac
#     {\frac{99}{10^5}}
#     {\frac{99}{10^5} + \frac{999}{10^5}}
# = \frac{99}{1098} = 0.09
# $$

# %%
99/(99+999)
# Out:
# 0.09016393442622951
